# %% [markdown]
# # 資料蒐集（公開 repo）
#
# 本 notebook 已停用。公開版本**不**包含可重現付費或訂閱資料擷取之程式碼或步驟。
#
# - 請閱讀 [`data/README.md`](../../data/README.md) 了解如何在本機放入具授權之資料。
# - 建模入口：[`main.py`](../../main.py)（無真實資料時會使用 `sample_data/processed/` 的合成示範）。
